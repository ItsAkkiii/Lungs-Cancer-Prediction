# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("survey lung cancer.csv")
df.head()
# Out:
#   GENDER  AGE  SMOKING  ...  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0      M   69        1  ...                      2           2          YES
# 1      M   74        2  ...                      2           2          YES
# 2      F   59        1  ...                      1           2           NO
# 3      M   63        2  ...                      2           2           NO
# 4      F   63        1  ...                      1           1           NO
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %%
df.describe()
# Out:
#               AGE     SMOKING  ...  SWALLOWING DIFFICULTY  CHEST PAIN
# count  309.000000  309.000000  ...             309.000000  309.000000
# mean    62.673139    1.563107  ...               1.469256    1.556634
# std      8.210301    0.496806  ...               0.499863    0.497588
# min     21.000000    1.000000  ...               1.000000    1.000000
# 25%     57.000000    1.000000  ...               1.000000    1.000000
# 50%     62.000000    2.000000  ...               1.000000    2.000000
# 75%     69.000000    2.000000  ...               2.000000    2.000000
# max     87.000000    2.000000  ...               2.000000    2.000000
#
# [8 rows x 14 columns]

# %%
# Checking the counts of label categories
df.isin(['?','NA']).sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
Total = df['LUNG_CANCER'].value_counts(normalize = True)
Total*100
# Out:
# YES    87.378641
# NO     12.621359
# Name: LUNG_CANCER, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
#sns.pairplot(data=df);

# %%
sns.countplot(x='LUNG_CANCER',hue='LUNG_CANCER',data=df);

# %%
sns.countplot(x='GENDER',hue='LUNG_CANCER',data=df);

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtypes == 'object':
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

# %%
df.corr()
# Out:
#                          GENDER       AGE  ...  CHEST PAIN  LUNG_CANCER
# GENDER                 1.000000  0.021306  ...    0.362958     0.067254
# AGE                    0.021306  1.000000  ...   -0.018104     0.089465
# SMOKING                0.036277 -0.084475  ...    0.120117     0.058179
# YELLOW_FINGERS        -0.212959  0.005205  ...   -0.104829     0.181339
# ANXIETY               -0.152127  0.053170  ...   -0.113634     0.144947
# PEER_PRESSURE         -0.275564  0.018685  ...   -0.094828     0.186388
# CHRONIC DISEASE       -0.204606 -0.012642  ...   -0.036938     0.110891
# FATIGUE               -0.083560  0.012614  ...   -0.010832     0.150673
# ALLERGY                0.154251  0.027990  ...    0.239433     0.327766
# WHEEZING               0.141207  0.055011  ...    0.147640     0.249300
# ALCOHOL CONSUMING      0.454268  0.058985  ...    0.331226     0.288533
# COUGHING               0.133303  0.169950  ...    0.083958     0.248570
# SHORTNESS OF BREATH   -0.064911 -0.017513  ...    0.024256     0.060738
# SWALLOWING DIFFICULTY -0.078161 -0.001270  ...    0.069027     0.259730
# CHEST PAIN             0.362958 -0.018104  ...    1.000000     0.190451
# LUNG_CANCER            0.067254  0.089465  ...    0.190451     1.000000
#
# [16 rows x 16 columns]

# %% [markdown]
# # Model Preparation
# Spilt into X & Y

# %%
x = df.drop("LUNG_CANCER",axis=1)
y = df["LUNG_CANCER"]

# %%
x
# Out:
#      GENDER  AGE  ...  SWALLOWING DIFFICULTY  CHEST PAIN
# 0         1   69  ...                      2           2
# 1         1   74  ...                      2           2
# 2         0   59  ...                      1           2
# 3         1   63  ...                      2           2
# 4         0   63  ...                      1           1
# ..      ...  ...  ...                    ...         ...
# 304       0   56  ...                      2           1
# 305       1   70  ...                      1           2
# 306       1   58  ...                      1           2
# 307       1   67  ...                      1           2
# 308       1   62  ...                      2           1
#
# [309 rows x 15 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 304    1
# 305    1
# 306    1
# 307    1
# 308    1
# Name: LUNG_CANCER, Length: 309, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.3, random_state=1, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
#step1-: initialise the model
ann = Sequential()

#step2 -: add the hidden layers
ann.add(Dense(units=4, activation="relu"))
ann.add(Dense(units=1, activation="sigmoid"))

#step3 -: establish the connection
ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

#step4 -: train the model
ann.fit(xtrain, ytrain, batch_size=30, epochs=100)

#step5 -: make prediction
ypred = ann.predict(xtest)

#step6 -: set the threshold
ypred = ypred>0.5
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9418 - accuracy: 0.2269
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9151 - accuracy: 0.2407
# Epoch 3/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8907 - accuracy: 0.2546
# Epoch 4/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8667 - accuracy: 0.2639
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8443 - accuracy: 0.3056
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8232 - accuracy: 0.3380
# Epoch 7/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8024 - accuracy: 0.3565
# Epoch 8/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7834 - accuracy: 0.3796
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7650 - accuracy: 0.4120
# Epoch 10/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7478 - accuracy: 0.4444
# Epoch 11/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7319 - accuracy: 0.4815
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7164 - accuracy: 0.5278
# Epoch 13/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7018 - accuracy: 0.5972
# Epoch 14/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.6204
# Epoch 15/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.6389
# Epoch 16/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.6435
# Epoch 17/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6574
# Epoch 18/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.6620
# Epoch 19/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6277 - accuracy: 0.6759
# Epoch 20/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6176 - accuracy: 0.6944
# Epoch 21/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.7083
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.7315
# Epoch 23/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5895 - accuracy: 0.7454
# Epoch 24/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5809 - accuracy: 0.7546
# Epoch 25/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5726 - accuracy: 0.7593
# Epoch 26/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5643 - accuracy: 0.7639
# Epoch 27/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5565 - accuracy: 0.7778
# Epoch 28/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5492 - accuracy: 0.7963
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5419 - accuracy: 0.8148
# Epoch 30/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5349 - accuracy: 0.8287
# Epoch 31/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.8380
# Epoch 32/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5215 - accuracy: 0.8426
# Epoch 33/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5155 - accuracy: 0.8380
# Epoch 34/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5095 - accuracy: 0.8565
# Epoch 35/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5035 - accuracy: 0.8704
# Epoch 36/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.8704
# Epoch 37/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4925 - accuracy: 0.8796
# Epoch 38/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.8796
# Epoch 39/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.8704
# Epoch 40/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4769 - accuracy: 0.8750
# Epoch 41/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4722 - accuracy: 0.8750
# Epoch 42/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4674 - accuracy: 0.8750
# Epoch 43/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.8750
# Epoch 44/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4583 - accuracy: 0.8750
# Epoch 45/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.8750
# Epoch 46/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.8750
# Epoch 47/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.8704
# Epoch 48/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.8704
# Epoch 49/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.8704
# Epoch 50/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.8704
# Epoch 51/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8657
# Epoch 52/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.8750
# Epoch 53/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4242 - accuracy: 0.8750
# Epoch 54/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8750
# Epoch 55/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8750
# Epoch 56/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8750
# Epoch 57/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4111 - accuracy: 0.8750
# Epoch 58/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.8750
# Epoch 59/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.8750
# Epoch 60/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4020 - accuracy: 0.8750
# Epoch 61/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.8750
# Epoch 62/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8750
# Epoch 63/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.8750
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3910 - accuracy: 0.8750
# Epoch 65/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.8750
# Epoch 66/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3856 - accuracy: 0.8750
# Epoch 67/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8750
# Epoch 68/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3804 - accuracy: 0.8750
# Epoch 69/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3779 - accuracy: 0.8750
# Epoch 70/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3754 - accuracy: 0.8750
# Epoch 71/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8750
# Epoch 72/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8750
# Epoch 73/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.8750
# Epoch 74/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8750
# Epoch 75/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8750
# Epoch 76/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3608 - accuracy: 0.8750
# Epoch 77/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8750
# Epoch 78/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8750
# Epoch 79/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8750
# Epoch 80/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3516 - accuracy: 0.8750
# Epoch 81/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3494 - accuracy: 0.8750
# Epoch 82/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3471 - accuracy: 0.8750
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8750
# Epoch 84/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8750
# Epoch 85/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3404 - accuracy: 0.8750
# Epoch 86/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3382 - accuracy: 0.8750
# Epoch 87/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3360 - accuracy: 0.8750
# Epoch 88/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8750
# Epoch 89/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3318 - accuracy: 0.8750
# Epoch 90/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3297 - accuracy: 0.8750
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8750
# Epoch 92/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3255 - accuracy: 0.8750
# Epoch 93/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3235 - accuracy: 0.8750
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8750
# Epoch 95/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3196 - accuracy: 0.8750
# Epoch 96/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3177 - accuracy: 0.8750
# Epoch 97/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3158 - accuracy: 0.8750
# Epoch 98/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3139 - accuracy: 0.8750
# Epoch 99/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3120 - accuracy: 0.8750
# Epoch 100/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3101 - accuracy: 0.8796

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.87      0.99      0.92        81
#
#     accuracy                           0.86        93
#    macro avg       0.43      0.49      0.46        93
# weighted avg       0.76      0.86      0.81        93
